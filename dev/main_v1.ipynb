# %%
import os
import pandas as pd
from tools.dataset import score_dataset
from tools.preprocessing.missing_values import get_missing_raio, delete_columns, impute_missing_values
from tools.preprocessing.outliers import delete_outliers, impute_outliers, get_limits
from tools.preprocessing.scaling import minmax
from tools.engineering.mi import mi_score

# %% [markdown]
# # 1. 데이터 로드

# %%
DATA_PATH = './data'

train = pd.read_csv(os.path.join(DATA_PATH, 'train.csv'))
test = pd.read_csv(os.path.join(DATA_PATH, 'test.csv'))

# train_origin = train.copy()
# test_origin = test.copy()

print(f'train shape: {train.shape}')
print(f'test shape: {test.shape}')
# Out:
# train shape: (79023, 76)
# test shape: (24353, 75)

# %%
# 데이터 일부 확인
train.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                       -0.000065
# 1                                        0.000014
# 2                                        0.000385
# 3                                             NaN
# 4                                       -0.000048
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                       0.255668                           -98.593887  ...
# 1                       0.130988                            16.592861  ...
# 2                       0.110018                            72.795837  ...
# 3                            NaN                                  NaN  ...
# 4                       0.121164                             4.121269  ...
#
#    Cloud_cloud_top_height  Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0             3664.436218               61085.809570              2615.120483
# 1             3651.190311               66969.478735              3174.572424
# 2             4216.986492               60068.894448              3516.282669
# 3             5228.507736               51064.547339              4180.973322
# 4             3980.598120               63751.125781              3355.710107
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                  15.568533              0.272292
# 1                   8.690601              0.256830
# 2                  21.103410              0.251101
# 3                  15.386899              0.262043
# 4                   8.114694              0.235847
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                  -12.628986                  35.632416
# 1                   30.359375                  39.557633
# 2                   15.377883                  30.401823
# 3                  -11.293399                  24.380357
# 4                   38.532263                  37.392979
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle  emission
# 0                -138.786423                 30.752140  3.750994
# 1                -145.183930                 27.251779  4.025176
# 2                -142.519545                 26.193296  4.231381
# 3                -132.665828                 28.829155  4.305286
# 4                -141.509805                 22.204612  4.347317
#
# [5 rows x 76 columns]

# %%
test_id = test['ID_LAT_LON_YEAR_WEEK']

train.drop(['ID_LAT_LON_YEAR_WEEK', 'year'], axis=1, inplace=True)
test.drop(['ID_LAT_LON_YEAR_WEEK', 'year'], axis=1, inplace=True)

# %% [markdown]
# # 2. 결측값 처리

# %%
# 삭제하지 않을 칼럼
PROTECTED_COLUMNS = ['latitude', 'longitude', 'week_no']

# %% [markdown]
# 결측값 비율이 높은 칼럼 삭제

# %%
train_deleted, deleted_columns = delete_columns(train, 0.3, target='emission')

print(f'삭제된 칼럼 개수: {len(deleted_columns)}')
# Out:
# 삭제된 칼럼 개수: 7

# %%
# 테스트 데이터에도 적용
test_deleted = test.drop(deleted_columns, axis=1)

# %%
# 결측값 제거 결과
data_list = [['train', train], ['train_deleted', train_deleted]]
results = []

for name, data in data_list:
    score = score_dataset(data, 'emission')
    results.append([name, score])

results
# Out:
# [['train', 9.103228178514371], ['train_deleted', 9.081446014439852]]

# %% [markdown]
# 칼럼을 삭제한 데이터셋의 스코어가 더 좋다.

# %% [markdown]
# 가장 이상적인 결측값 대체법 찾기

# %%
methods = ['mean', 'linear', 'fill']
results = []

for method in methods:
    train_imputed, _ = impute_missing_values(train_deleted, method)
    score = score_dataset(train_imputed, 'emission')
    results.append([method, score])
    print(f'method "{method}" 계산 완료')

results
# Out:
# method "mean" 계산 완료
# method "linear" 계산 완료
# method "fill" 계산 완료
# [['mean', 8.956733358720077],
#  ['linear', 8.898703621611462],
#  ['fill', 8.84700168290635]]

# %%
best_method = sorted(results, key=lambda x: x[1])[0]
print(f'best method: {best_method}')
# Out:
# best method: ['fill', 8.84700168290635]

# %%
train_imputed, _ = impute_missing_values(train_deleted, best_method[0])
test_imputed, _ = impute_missing_values(test_deleted, best_method[0])
# test_imputed = test_deleted.fillna(tool)

# %%
train_now = train_imputed
test_now = test_imputed

# %% [markdown]
# # 3. 이상치 처리

# %% [markdown]
# numeric 칼럼에 대해 이상치 처리

# %%
outliers_columns = list(train_now.select_dtypes(exclude=['O']).columns)
outliers_columns.remove('emission')
outliers_columns[:10]
# Out:
# ['latitude',
#  'longitude',
#  'year',
#  'week_no',
#  'SulphurDioxide_SO2_column_number_density',
#  'SulphurDioxide_SO2_column_number_density_amf',
#  'SulphurDioxide_SO2_slant_column_number_density',
#  'SulphurDioxide_cloud_fraction',
#  'SulphurDioxide_sensor_azimuth_angle',
#  'SulphurDioxide_sensor_zenith_angle']

# %% [markdown]
# 이상치 기준이 되는 상한, 하한 구하기

# %%
limits = get_limits(train_now, outliers_columns)
limits.items()
# Out:
# dict_items([('latitude', [0.41900000000000026, -4.173]), ('longitude', [32.2845, 27.448500000000003]), ('year', [2024.0, 2016.0]), ('week_no', [78.0, -26.0]), ('SulphurDioxide_SO2_column_number_density', [0.000513877984210504, -0.0004540995530549583]), ('SulphurDioxide_SO2_column_number_density_amf', [1.2902691189624758, 0.36975534250679815]), ('SulphurDioxide_SO2_slant_column_number_density', [0.00041078522838457806, -0.00036556129722763]), ('SulphurDioxide_cloud_fraction', [0.3579012532719073, -0.031659258299414794]), ('SulphurDioxide_sensor_azimuth_angle', [241.72112203980677, -234.71471377764252]), ('SulphurDioxide_sensor_zenith_angle', [74.43875067040783, 1.1427080050441525]), ('SulphurDioxide_solar_azimuth_angle', [65.9132108688354, -239.83539295196528]), ('SulphurDioxide_solar_zenith_angle', [43.08536106871162, 12.65385854363208]), ('SulphurDioxide_SO2_column_number_density_15km', [0.00017373174944799763, -0.00015564230224563433]), ('CarbonMonoxide_CO_column_number_density', [0.04628022628991814, 0.01879345377729752]), ('CarbonMonoxide_H2O_column_number_density', [3503.109402540155, 626.6972702605215]), ('CarbonMonoxide_cloud_height', [4948.7861052913, 738.1627190049574]), ('CarbonMonoxide_sensor_altitude', [830416.2547317209, 829461.3509822149]), ('CarbonMonoxide_sensor_azimuth_angle', [116.40144130025249, -134.83134125462436]), ('CarbonMonoxide_sensor_zenith_angle', [63.762712644386916, 12.138600177442193]), ('CarbonMonoxide_solar_azimuth_angle', [67.97241726024971, -241.76097873749748]), ('CarbonMonoxide_solar_zenith_angle', [42.70960935583452, 13.205925910813626]), ('NitrogenDioxide_NO2_column_number_density', [6.620049280203979e-05, 2.106584237462847e-05]), ('NitrogenDioxide_tropospheric_NO2_column_number_density', [2.938082603089073e-05, -6.021188132097263e-06]), ('NitrogenDioxide_stratospheric_NO2_column_number_density', [4.2518414873444926e-05, 2.1318611431297196e-05]), ('NitrogenDioxide_NO2_slant_column_number_density', [0.0001425801047532783, 4.904376745293616e-05]), ('NitrogenDioxide_tropopause_pressure', [11023.258546119843, 7167.0945355713675]), ('NitrogenDioxide_absorbing_aerosol_index', [-0.248766170698705, -3.4822848999460394]), ('NitrogenDioxide_cloud_fraction', [0.2189818425379118, -0.030265648388310376]), ('NitrogenDioxide_sensor_altitude', [830575.5079762744, 829420.8200394682]), ('NitrogenDioxide_sensor_azimuth_angle', [260.44251253327604, -312.4995479233536]), ('NitrogenDioxide_sensor_zenith_angle', [77.43306189252705, -3.465777049342808]), ('NitrogenDioxide_solar_azimuth_angle', [61.485714479354954, -235.38107550891738]), ('NitrogenDioxide_solar_zenith_angle', [43.19224121741928, 13.670504156541881]), ('Formaldehyde_tropospheric_HCHO_column_number_density', [0.00033516171110427404, -8.811935288152346e-05]), ('Formaldehyde_tropospheric_HCHO_column_number_density_amf', [1.949909960365463, 0.5362745833562541]), ('Formaldehyde_HCHO_slant_column_number_density', [0.0003106730627377177, -0.0001439035777068886]), ('Formaldehyde_cloud_fraction', [0.5031768863164374, -0.04058332276125523]), ('Formaldehyde_solar_zenith_angle', [43.624093277212225, 12.556037710311177]), ('Formaldehyde_solar_azimuth_angle', [66.65840975443523, -240.507905960083]), ('Formaldehyde_sensor_zenith_angle', [74.0335571102672, 8.3385106411288]), ('Formaldehyde_sensor_azimuth_angle', [142.04694466190458, -154.18292040736165]), ('UvAerosolIndex_absorbing_aerosol_index', [-0.1439187944126723, -2.5372625370772934]), ('UvAerosolIndex_sensor_altitude', [830372.1642267187, 829572.1960803838]), ('UvAerosolIndex_sensor_azimuth_angle', [38.59376673318068, -64.18024041052]), ('UvAerosolIndex_sensor_zenith_angle', [56.11245116870805, 23.201869546819264]), ('UvAerosolIndex_solar_azimuth_angle', [68.45219340556118, -242.62560457980834]), ('UvAerosolIndex_solar_zenith_angle', [41.77851657877103, 14.666100311887579]), ('Ozone_O3_column_number_density', [0.12526444993501304, 0.10999672519510881]), ('Ozone_O3_column_number_density_amf', [2.94831616282 ...

# %%
train_outliers_deleted, deleted_indices = delete_outliers(train_now, outliers_columns, limits)
train_impute_outliers = impute_outliers(train_now, outliers_columns, limits)

# %%
# 삭제된 행의 개수
len(train_outliers_deleted)
# Out:
# 45397

# %% [markdown]
# 이상치 처리 비교(이상치 처리 전: 8.75663387517149)

# %%
outliers_dfs = [['deleted', train_outliers_deleted], ['imputed', train_impute_outliers]]
results = []

for name, outliers_df in outliers_dfs:
    score = score_dataset(outliers_df, 'emission')
    results.append([name, score])

results
# Out:
# [['deleted', 8.49429524751788], ['imputed', 8.7388773949861]]

# %% [markdown]
# 이상치가 있는 행을 제거했을 때가 가장 이상적인 score 기록
# 그러나 너무 많은 행이 삭제되므로 값을 대체

# %%
test_impute_outliers = impute_outliers(test_now, outliers_columns, limits)

# %%
train_now = train_impute_outliers
test_now = test_impute_outliers

# %% [markdown]
# # 4. Scaling

# %%
scaling_columns = set(train_outliers_deleted.select_dtypes(exclude=['O']).columns)
no_scaling_columns = set(['emission', 'latitude', 'longitude', 'year', 'week_no'])

scaling_columns = list(scaling_columns - no_scaling_columns)

# %%
train_scaled, scaler = minmax(train_now, scaling_columns)
train_scaled.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                  0.357198
# 1                                  0.490328
# 2                                  1.000000
# 3                                  0.694011
# 4                                  0.387750
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.253406
# 1                                      0.389411
# 2                                      0.411122
# 3                                      0.372066
# 4                                      0.333010
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                        0.386722
# 1                                        0.488405
# 2                                        0.966374
# 3                                        0.687952
# 4                                        0.409530
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                       0.852234                             0.268351  ...
# 1                       0.436631                             0.650229  ...
# 2                       0.366730                             0.836558  ...
# 3                       0.385307                             0.722720  ...
# 4                       0.403884                             0.608882  ...
#
#    Cloud_cloud_top_height  Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0                0.256252                   0.533547                 0.212175
# 1                0.254557                   0.651140                 0.288041
# 2                0.326947                   0.513223                 0.334380
# 3                0.456366                   0.333259                 0.424517
# 4                0.296703                   0.586817                 0.312605
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                   0.319321              0.500316
# 1                   0.159290              0.437434
# 2                   0.448103              0.414133
# 3                   0.315095              0.458633
# 4                   0.145890              0.352094
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                    0.486670                   0.368867
# 1                    0.758456                   0.483222
# 2                    0.663738                   0.216482
# 3                    0.495114                   0.041056
# 4                    0.810127                   0.420158
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle  emission
# 0                   0.112206                  0.596886  3.750994
# 1                   0.063300                  0.468260  4.025176
# 2                   0.083668                  0.429365  4.231381
# 3                   0.158996                  0.526223  4.305286
# 4                   0.091387                  0.282795  4.347317
#
# [5 rows x 69 columns]

# %%
score = score_dataset(train_scaled, 'emission')
score
# Out:
# 8.848195284542431

# %% [markdown]
# scaling이 큰 의미가 없다.

# %%
# 테스트 데이터에도 scaling 수행
test_scaled, _ = minmax(test_now, scaling_columns)
test_scaled.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year   week_no  \
# 0  ID_-0.510_29.290_2022_00       1.0   0.321429   0.0  0.000000
# 1  ID_-0.510_29.290_2022_01       1.0   0.321429   0.0  0.020833
# 2  ID_-0.510_29.290_2022_02       1.0   0.321429   0.0  0.041667
# 3  ID_-0.510_29.290_2022_03       1.0   0.321429   0.0  0.062500
# 4  ID_-0.510_29.290_2022_04       1.0   0.321429   0.0  0.083333
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                  0.201496
# 1                                  0.281705
# 2                                  0.223644
# 3                                  0.260880
# 4                                  0.129779
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.364783
# 1                                      0.258898
# 2                                      0.195479
# 3                                      0.263137
# 4                                      0.177366
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                        0.232919
# 1                                        0.313628
# 2                                        0.253280
# 3                                        0.292780
# 4                                        0.169897
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                       0.528106                             0.374117  ...
# 1                       0.000000                             0.692547  ...
# 2                       0.266256                             0.244992  ...
# 3                       0.670153                             0.677150  ...
# 4                       0.681235                             0.692364  ...
#
#    Cloud_cloud_top_pressure  Cloud_cloud_top_height  \
# 0                  0.217114                0.666251
# 1                  0.425313                0.468456
# 2                  0.185696                0.717032
# 3                  0.463821                0.422735
# 4                  0.392962                0.505429
#
#    Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0                   0.233233                 0.653909
# 1                   0.457115                 0.448800
# 2                   0.200269                 0.706567
# 3                   0.501200                 0.401388
# 4                   0.424518                 0.487140
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                   0.050704              0.457539
# 1                   0.079539              0.563887
# 2                   0.073832              0.511086
# 3                   0.082134              0.587373
# 4                   0.092811              0.545809
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                    0.035528                   0.516122
# 1                    0.405666                   0.650183
# 2                    0.775774                   0.704603
# 3                    0.437813                   0.646146
# 4                    0.499273                   0.461078
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle
# 0                   0.121612                  0.763380
# 1                   0.077314                  0.654085
# 2                   0.028521                  0.485473
# 3                   0.105905                  0.598489
# 4                   0.102160                  0.467045
#
# [5 rows x 56 columns]

# %%
train_now = train_impute_outliers
test_now = test_impute_outliers

# %% [markdown]
# # 5. Mutual Information

# %%
import pandas as pd
from sklearn.feature_selection import mutual_info_regression


def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores


def mi_score(df, target, threshold, corr=False, corr_threshold=None):
    df_columns = list(df.columns)
    df_mi = df.copy()
    
    X = df_mi.drop(target, axis=1)
    y = df_mi.pop(target)
    
    X_numeric = X.select_dtypes(exclude=['O'])
    object_columns = list(X.select_dtypes(include=['O']).columns)
    
    discrete_features = X_numeric.dtypes == int

    mi_scores = make_mi_scores(X_numeric, y, discrete_features)

    mi_selected_columns = list(mi_scores.loc[mi_scores >= threshold].index)


    # 상관관계가 일정 수준 이상일 경우에도 칼럼 포함
    corr_selected_columns = []
    if corr:
        df_numeric = df.select_dtypes(exclude=['O'])
        df_corr = df_numeric.corr()

        corr = abs(df_corr[target])
        corr_selected_columns = list(corr[corr >= corr_threshold].index)

    selected_columns_all = list(set(mi_selected_columns + corr_selected_columns)) + object_columns
    df_selected = df.loc[:, selected_columns_all]

    return df_selected, selected_columns_all

# %%
train_mi, mi_selected_columns = mi_score(train_now, 'emission', 0.01, corr=True, corr_threshold=0.1)
# Out:
# ['NitrogenDioxide_sensor_azimuth_angle', 'Ozone_solar_azimuth_angle', 'emission', 'week_no', 'SulphurDioxide_SO2_column_number_density_amf', 'NitrogenDioxide_sensor_zenith_angle', 'NitrogenDioxide_stratospheric_NO2_column_number_density', 'UvAerosolIndex_sensor_azimuth_angle', 'Cloud_solar_azimuth_angle', 'Cloud_surface_albedo', 'Formaldehyde_solar_azimuth_angle', 'Cloud_cloud_top_height', 'Formaldehyde_sensor_zenith_angle', 'longitude', 'NitrogenDioxide_absorbing_aerosol_index', 'NitrogenDioxide_tropopause_pressure', 'UvAerosolIndex_solar_azimuth_angle', 'UvAerosolIndex_sensor_zenith_angle', 'CarbonMonoxide_sensor_altitude', 'SulphurDioxide_solar_azimuth_angle', 'Ozone_sensor_zenith_angle', 'Cloud_cloud_base_pressure', 'Formaldehyde_sensor_azimuth_angle', 'UvAerosolIndex_solar_zenith_angle', 'SulphurDioxide_sensor_azimuth_angle', 'NitrogenDioxide_solar_azimuth_angle', 'NitrogenDioxide_sensor_altitude', 'SulphurDioxide_SO2_column_number_density', 'SulphurDioxide_sensor_zenith_angle', 'Ozone_cloud_fraction', 'latitude', 'year', 'CarbonMonoxide_H2O_column_number_density', 'Cloud_sensor_azimuth_angle', 'Formaldehyde_tropospheric_HCHO_column_number_density_amf', 'CarbonMonoxide_sensor_zenith_angle', 'Cloud_cloud_base_height', 'NitrogenDioxide_NO2_column_number_density', 'SulphurDioxide_SO2_column_number_density_15km', 'CarbonMonoxide_solar_azimuth_angle', 'UvAerosolIndex_sensor_altitude', 'CarbonMonoxide_sensor_azimuth_angle', 'Ozone_sensor_azimuth_angle', 'ID_LAT_LON_YEAR_WEEK']
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2019_00    -0.510     29.290  2019        0
# 1      ID_-0.510_29.290_2019_01    -0.510     29.290  2019        1
# 2      ID_-0.510_29.290_2019_02    -0.510     29.290  2019        2
# 3      ID_-0.510_29.290_2019_03    -0.510     29.290  2019        3
# 4      ID_-0.510_29.290_2019_04    -0.510     29.290  2019        4
# ...                         ...       ...        ...   ...      ...
# 79018  ID_-3.299_30.301_2021_48    -3.299     30.301  2021       48
# 79019  ID_-3.299_30.301_2021_49    -3.299     30.301  2021       49
# 79020  ID_-3.299_30.301_2021_50    -3.299     30.301  2021       50
# 79021  ID_-3.299_30.301_2021_51    -3.299     30.301  2021       51
# 79022  ID_-3.299_30.301_2021_52    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# 2                                      0.000514
# 3                                      0.000218
# 4                                     -0.000079
# ...                                         ...
# 79018                                  0.000284
# 79019                                  0.000083
# 79020                                  0.000025
# 79021                                 -0.000034
# 79022                                 -0.000091
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 0                                          0.603019
# 1                                          0.728214
# 2                                          0.748199
# 3                                          0.712247
# 4                                          0.676296
# ...                                             ...
# 79018                                      1.195643
# 79019                                      1.130868
# 79020                                      1.005133
# 79021                                      0.879397
# 79022                                      0.871951
#
#        SulphurDioxide_SO2_slant_column_number_density  \
# 0                                           -0.000065
# 1                                            0.000014
# 2                                            0.000385
# 3                                            0.000169
# 4                                           -0.000048
# ...                                               ...
# 79018                                        0.000340
# 79019                                        0.000063
# 79020                                        0.000018
# 79021                                       -0.000028
# 79022                                       -0.000079
#
#        SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# 0                           0.255668                           -98.593887
# 1                           0.130988                            16.592861
# 2                           0.110018                            72.795837
# 3                           0.115591                            38.458553
# 4                           0.121164                             4.121269
# ...                              ...                                  ...
# 79018                       0.191313                            72.820518
# 79019                       0.177222                           -12.856753
# 79020                       0.180716                           -56.600790
# 79021                       0.184209                          -100.344827
# 79022                       0.000000                            76.825638
#
#        ...  Cloud_cloud_top_height  Cloud_cloud_base_pressure  \
# 0      ...             3664.436218               61085.809570
# 1      ...             3651.190311               66969.478735
# 2      ...             4216.986492               60068.894448
# 3      ...             5228.507736               51064.547339
# 4      ...             3980.598120               63751.125781
# ...    ...                     ...                        ...
# 79018  ...             5459.185355               60657.101913
# 79019  ...             5606.449457               60168.191528
# 79020  ...             6222.646776               56596.027209
# 79021  ...             7896.456885               46533.348194
# 79022  ...             7553.295016               47771.681887
#
#        Cloud_cloud_base_height  Cloud_cloud_optical_depth  \
# 0                  2615.120483                  15.568533
# 1                  3174.572424                   8.690601
# 2                  3516.282669                  21.103410
# 3                  4180.973322                  15.386899
# 4                  3355.710107                   8.114694
# ...                        ...                        ...
# 79018              4590.879504                  20.245954
# 79019              4659.130378                   6.104610
# 79020              5222.646823                  14.817885
# 79021              6946.858022                  32.594768
# 79022              6553.295018                  19.464032
#
#        Cloud_surface_albedo  Cloud_sensor_azimuth_angle  \
# 0                  0.272292                  -12.628986
# 1                  0.256830                   30.359375
# 2                  0.251101                   15.377883
# 3                  0.262043                  -11.293399
# 4                  0.235847                   38.532263
# ...                     ...                         ...
# 79018              0.304797                  -35.140368
# 79019              0.314015                    4.667058
# 79020              0.288058                   -0.340922
# 79021              0.274047                    8.427699
# 79022              0.226276                  -12.808528
#
#        Cloud_sensor_zenith_angle  Cloud_solar_azimuth_angle  \
# 0                      35.632416                -138.786423
# 1                      39.557633                -145.183930
# 2                      30.401823                -142.519545
# 3                      24.380357                -132.665828
# 4                      37.392979                -141.509805
# ...                          ...                        ...
# 79018                  40.113533                -129.935508
# 79019                  47.528435                -134.252871
# 79020                  35.328098                -134.731723
# 79021                  48.295652                -139.447849
# 79022                  47.923441                -136.299984
#
#        Cloud_solar_zenith_angle   emission
# 0                     30.752140   3.750994
# 1                     27.251779   4.025176
# 2                     26.193296   4.231381
# 3                     28.829155   4.305286
# 4                     22.204612   4.347317
# ...                         ...        ...
# 79018                 32.095214  29.404171
# 79019                 30.771469  29.186497
# 79020                 30.716166  29.131205
# 79021                 29.112868  28.125792
# 79022                 30.246387  27.239302
#
# [79023 rows x 69 columns]

# %%
train_mi.head()
# Out:
#    NitrogenDioxide_sensor_azimuth_angle  Ozone_solar_azimuth_angle  emission  \
# 0                              5.471037                -138.786446  3.750994
# 1                              5.471037                -143.097868  4.025176
# 2                             72.795837                -135.364627  4.231381
# 3                             29.682020                -137.489602  4.305286
# 4                            -13.431798                -136.448518  4.347317
#
#    week_no  SulphurDioxide_SO2_column_number_density_amf  \
# 0        0                                      0.603019
# 1        1                                      0.728214
# 2        2                                      0.748199
# 3        3                                      0.712247
# 4        4                                      0.676296
#
#    NitrogenDioxide_sensor_zenith_angle  \
# 0                            35.265195
# 1                            35.265195
# 2                            52.868816
# 3                            43.973720
# 4                            35.078624
#
#    NitrogenDioxide_stratospheric_NO2_column_number_density  \
# 0                                            0.00003
# 1                                            0.00003
# 2                                            0.00003
# 3                                            0.00003
# 4                                            0.00003
#
#    UvAerosolIndex_sensor_azimuth_angle  Cloud_solar_azimuth_angle  \
# 0                           -12.628979                -138.786423
# 1                            16.152492                -145.183930
# 2                           -41.557633                -142.519545
# 3                            -0.001270                -132.665828
# 4                            -0.604325                -141.509805
#
#    Cloud_surface_albedo  ...  \
# 0              0.272292  ...
# 1              0.256830  ...
# 2              0.251101  ...
# 3              0.262043  ...
# 4              0.235847  ...
#
#    Formaldehyde_tropospheric_HCHO_column_number_density_amf  \
# 0                                           0.863230
# 1                                           1.172826
# 2                                           1.175467
# 3                                           1.022274
# 4                                           0.869081
#
#    CarbonMonoxide_sensor_zenith_angle  Cloud_cloud_base_height  \
# 0                           52.775928              2615.120483
# 1                           38.982368              3174.572424
# 2                           52.344378              3516.282669
# 3                           39.676184              4180.973322
# 4                           33.703073              3355.710107
#
#    NitrogenDioxide_NO2_column_number_density  \
# 0                                   0.000047
# 1                                   0.000047
# 2                                   0.000031
# 3                                   0.000041
# 4                                   0.000051
#
#    SulphurDioxide_SO2_column_number_density_15km  \
# 0                                      -0.000027
# 1                                       0.000012
# 2                                       0.000154
# 3                                       0.000063
# 4                                      -0.000028
#
#    CarbonMonoxide_solar_azimuth_angle  UvAerosolIndex_sensor_altitude  \
# 0                         -149.875565                   829864.546875
# 1                         -140.158048                   829747.856973
# 2                         -133.683714                   829892.960629
# 3                         -142.575915                   829794.848214
# 4                         -134.854258                   829736.142857
#
#    CarbonMonoxide_sensor_azimuth_angle  Ozone_sensor_azimuth_angle  \
# 0                            71.111977                  -12.628979
# 1                            -1.019594                   24.464335
# 2                           -54.801144                  -41.557633
# 3                            28.916541                   -0.001270
# 4                           -12.501663                   -0.604325
#
#        ID_LAT_LON_YEAR_WEEK
# 0  ID_-0.510_29.290_2019_00
# 1  ID_-0.510_29.290_2019_01
# 2  ID_-0.510_29.290_2019_02
# 3  ID_-0.510_29.290_2019_03
# 4  ID_-0.510_29.290_2019_04
#
# [5 rows x 44 columns]

# %%
score = score_dataset(train_mi, 'emission')
score
# Out:
# 8.688779766088285

# %% [markdown]
# MI 스코어 적용 후 score 개선

# %%
mi_selected_columns.remove('emission')

test_mi = test_now.loc[:, mi_selected_columns]

# %%
train_now = train_mi
test_now = test_mi

# %% [markdown]
# # 6. Clustering

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import OneHotEncoder


def kmc(df_origin, features, cluster=None, n_clusters=10, encoder=None):
    df = df_origin.copy()
    X = df_origin.copy()
    X = X.loc[:, features]
    X_scaled = (X - X.mean(axis=0)) / X.std(axis=0)

    if not cluster:
        cluster = KMeans(n_clusters=n_clusters, random_state=0)

    X["cluster"] = cluster.fit_predict(X_scaled)
    
    df['cluster'] = X["cluster"]

    ## one hot encoding ##
    # sparse=False: 인코딩된 칼럼이 numpy array type을 갖도록
    if not encoder:
        encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
        encoder.fit(df[['cluster']])

    df['cluster'] = df['cluster'].astype('O')
    
    df_encoded = pd.DataFrame(encoder.transform(df[['cluster']]))
    df_encoded.index = df.index
    df = df.drop('cluster', axis=1)

    df = pd.concat([df, df_encoded], axis=1)

    return df, cluster

# %%
features = ['latitude', 'longitude', 'week_no']

# %%
train_clustered, cluster = kmc(train_scaled, features)
# Out:
# c:\Users\loven\dev\kaggle_competition\carbon\carbon\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\loven\dev\kaggle_competition\carbon\carbon\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
score = score_dataset(train_clustered, 'emission')
score
# Out:
# 8.464154460464664

# %% [markdown]
# clustering 진행 후 스코어가 오히려 악화되었으므로 clustering 적용 안 함

# %% [markdown]
# # 7. 최종 데이터셋

# %%
train_final = train_now.copy()
test_final = test_now.copy()

# %%
print(train_final.shape)
print(test_final.shape)
# Out:
# (79023, 44)
# (24353, 43)

# %%
# 데이터 저장
data_name = os.path.join(DATA_PATH, 'train_final_0806_2.csv')
train_final.to_csv(data_name)

data_name = os.path.join(DATA_PATH, 'test_final_0806_2.csv')
test_final.to_csv(data_name)
